# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinal-Senadheera/SimpleANN/blob/main/SimpleANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing packages

# %%
import pandas as pd

# %% [markdown]
# importing data

# %%
df = pd.read_csv('Mobile_Price_Classification-220531-204702.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# identifying independent and dependent axis

# %%
x = df.drop(['price_range'], axis = 1)
y = df['price_range']

# %%
x.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: price_range, dtype: int64

# %% [markdown]
# Seperating train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y, test_size = 0.25, random_state = 2)

# %% [markdown]
# Importing dependencies for model

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout

# %% [markdown]
# Building the model

# %%
model = Sequential()
model.add(Dense(units = 8, activation = 'relu', input_dim = len(X_train.columns)))
model.add(Dense(units = 4, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 168
#
#  dense_1 (Dense)             (None, 4)                 36
#
#  dense_2 (Dense)             (None, 1)                 5
#
# ...
# Total params: 209
# Trainable params: 209
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'sgd', metrics = 'accuracy')

# %% [markdown]
# Feeding data

# %%
model.fit(X_train,Y_train, validation_data = (X_test,Y_test), epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 5ms/step - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6936 - val_accuracy: 0.4820
# Epoch 2/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6936 - val_accuracy: 0.4820
# Epoch 3/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6936 - val_accuracy: 0.4820
# Epoch 4/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6936 - val_accuracy: 0.4820
# Epoch 5/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6936 - val_accuracy: 0.4820
# Epoch 6/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6936 - val_accuracy: 0.4820
# Epoch 7/100
# ...

# %% [markdown]
# Saving weights

# %%
model.save('weights.h5')
